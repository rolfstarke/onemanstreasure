# %% [markdown]
# Connect to your own drive and access the shared folder -> You must manually add a shortcut to the shared folder into your "My Drive" -> Go to Google Drive -> Find the shared folder under "Shared with me"
# -> Right-click it -> Add shortcut to Drive -> Choose a location in "My Drive"
#
# **Files that are shared with you do not show up directly in /content/drive/MyDrive/OneMansTreasure**
#
# **dort bitte alle datensätze und trainierten modelle abspeichern**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **datasets direkt von einer website downloaden und in den entsprechenden ordner verschieben. achtet dabei in welchem format das dataset ist yolo8, yolo11, etc**
#
# **Oder download dataset from roboflow-> Get a code snippet or ZIP file -> yolo8 -> Show download code, Custom train this dataset using the provided code snippet in a notebook -> copy code into next code block**

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gPmajYyPhl8ZUHeYjtj0")
project = rf.workspace("pcz").project("roof-utb0w-fpnlh")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 88.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.11.0.86
#     Uninstalling opencv-python-headless-4.11.0.86:
#       Successfully uninstalled opencv-python-headless-4.11.0.86
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to roof-1 in yolov8:: 100%|██████████| 3894/3894 [00:00<00:00, 5932.98it/s]

# %% [markdown]
# **roboflow token hier abrufen:**
# https://app.roboflow.com/auth-cli

# %%
# !roboflow login
# Out:
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here:

# %% [markdown]
# **Finally, prepare a command in the following format:**
#
# **roboflow import -w testupload -p project-1-8zgld /path/to/dataset/folder**
#
# **Here are the arguments you need to specify:**
#
#     -w testupload: This is the name of the batch that will be created.
#
#     -p <project-id>: This is your project ID.
#
#
#
# https://docs.roboflow.com/datasets/adding-data https://docs.roboflow.com/developer/authentication/workspace-and-project-ids

# %%
# !roboflow import -w testupload -p tafeln4 "/content/drive/MyDrive/OneMansTreasure/table/images.cv_o3q0fgklvlfglxvovsrkbh"
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Traceback (most recent call last):
#   File "/usr/local/bin/roboflow", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/roboflow/roboflowpy.py", line 571, in main
#     args.func(args)
#   File "/usr/local/lib/python3.11/dist-packages/roboflow/roboflowpy.py", line 53, in import_dataset
#     workspace.upload_dataset(
#   File "/usr/local/lib/python3.11/dist-packages/roboflow/core/workspace.py", line 308, in upload_dataset
#     parsed_dataset = folderparser.parsefolder(dataset_path, is_classification=is_classification)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/roboflow/util/folderparser.py", line 38, in parsefolder
#     _map_annotations_to_images_1tomany(images, annotations)
# ...
